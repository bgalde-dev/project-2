# %%
# Dependencies
import pandas as pd
import db_connect
import os

print(os.getcwd())

my_connection = db_connect.DBConnector()
# Out:
# C:\Users\Ben Galde\workspace\service-industry\src\py
# C:\Users\Ben Galde\workspace\service-industry\src\py
# Config file loading successful

# %%
my_df = my_connection.get_raw_data("average-salary")
my_df.groupby(['ID Industry Group','Year'])
my_df
# Out:
#                            _id  ID Industry Group  \
# 0     6068cffd8c5ea93b98bbcfc5                111
# 1     6068cffd8c5ea93b98bbcfc6                112
# 2     6068cffd8c5ea93b98bbcfc7               1133
# 3     6068cffd8c5ea93b98bbcfc8                113
# 4     6068cffd8c5ea93b98bbcfc9                114
# ...                        ...                ...
# 1597  6068cffd8c5ea93b98bbd602             928110
# 1598  6068cffd8c5ea93b98bbd603             928110
# 1599  6068cffd8c5ea93b98bbd604             928110
# 1600  6068cffd8c5ea93b98bbd605             928110
# 1601  6068cffd8c5ea93b98bbd606             928110
#
#                                 Industry Group  ID Year  Year  \
# 0                                      Farming     2019  2019
# 1              Animal production & aquaculture     2019  2019
# 2                                      Logging     2019  2019
# 3                      Forestry except logging     2019  2019
# ...
